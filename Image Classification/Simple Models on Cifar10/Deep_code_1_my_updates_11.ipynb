# %%
import keras
from keras.datasets import cifar10
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
import os
from keras.layers import Flatten, Dense
from keras.optimizers import SGD
from keras.layers import Input
from keras.models import Model

from keras.layers.normalization import BatchNormalization
from keras.layers import Dropout

from keras.layers import GlobalAveragePooling2D
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Data

# %%
# airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

#normalization
X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %% [markdown]
# Network structure or graph

# %%
#input layer
input_img = Input(shape = (32, 32, 3))

# %%
# no batch normalization + global max pooling

tower_1 = Conv2D(64, (3,3), padding='same', activation='relu')(input_img)

tower_1 = Conv2D(64, (5,5), padding='same', activation='relu')(tower_1)
tower_1 = Dropout(0.5)(tower_1)

tower_1 = Conv2D(64, (5,5), padding='same', activation='relu')(tower_1)
tower_1 = Dropout(0.5)(tower_1)

tower_1 = Conv2D(64, (5,5), padding='same', activation='relu')(tower_1)
tower_1 = Dropout(0.5)(tower_1)

tower_1 = MaxPooling2D((5,5), strides=(1,1), padding='same')(tower_1)
tower_1 = Dropout(0.5)(tower_1)

tower_1 = Conv2D(64, (3,3), padding='same', activation='relu')(tower_1)
tower_1 = Dropout(0.5)(tower_1)

output = GlobalAveragePooling2D()(tower_1)
#output = Flatten()(tower_1)

out = Dense(10, activation='softmax')(output)

# %%
model = Model(inputs = input_img, outputs = out)
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        102464
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        102464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        102464
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 346,762
# Trainable params: 346,762
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epochs = 100
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 36s 714us/step - loss: 2.2534 - accuracy: 0.1319 - val_loss: 2.1993 - val_accuracy: 0.1533
# Epoch 2/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 1.9019 - accuracy: 0.2608 - val_loss: 2.0074 - val_accuracy: 0.2234
# Epoch 3/100
# 50000/50000 [==============================] - 34s 670us/step - loss: 1.6276 - accuracy: 0.3848 - val_loss: 1.7930 - val_accuracy: 0.3206
# Epoch 4/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 1.4321 - accuracy: 0.4674 - val_loss: 1.5762 - val_accuracy: 0.4373
# Epoch 5/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 1.2770 - accuracy: 0.5341 - val_loss: 1.3739 - val_accuracy: 0.5277
# Epoch 6/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 1.1539 - accuracy: 0.5823 - val_loss: 1.3546 - val_accuracy: 0.5306
# Epoch 7/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 1.0710 - accuracy: 0.6147 - val_loss: 1.1806 - val_accuracy: 0.6123
# Epoch 8/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 1.0143 - accuracy: 0.6375 - val_loss: 1.1769 - val_accuracy: 0.6157
# Epoch 9/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.9629 - accuracy: 0.6571 - val_loss: 1.1537 - val_accuracy: 0.6236
# Epoch 10/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.9263 - accuracy: 0.6698 - val_loss: 1.1579 - val_accuracy: 0.5911
# Epoch 11/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.8876 - accuracy: 0.6859 - val_loss: 1.0063 - val_accuracy: 0.6593
# Epoch 12/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.8517 - accuracy: 0.6975 - val_loss: 1.1070 - val_accuracy: 0.6303
# Epoch 13/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.8199 - accuracy: 0.7103 - val_loss: 1.0653 - val_accuracy: 0.6427
# Epoch 14/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.8026 - accuracy: 0.7158 - val_loss: 1.1065 - val_accuracy: 0.6215
# Epoch 15/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.7829 - accuracy: 0.7212 - val_loss: 1.0115 - val_accuracy: 0.6620
# Epoch 16/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.7619 - accuracy: 0.7311 - val_loss: 1.0296 - val_accuracy: 0.6577
# Epoch 17/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.7433 - accuracy: 0.7356 - val_loss: 0.9410 - val_accuracy: 0.6900
# Epoch 18/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.7238 - accuracy: 0.7436 - val_loss: 0.9563 - val_accuracy: 0.6865
# Epoch 19/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.7057 - accuracy: 0.7481 - val_loss: 0.9007 - val_accuracy: 0.7198
# Epoch 20/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.6943 - accuracy: 0.7524 - val_loss: 0.9350 - val_accuracy: 0.7130
# Epoch 21/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.6830 - accuracy: 0.7567 - val_loss: 0.8781 - val_accuracy: 0.7200
# Epoch 22/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.6669 - accuracy: 0.7647 - val_loss: 0.8375 - val_accuracy: 0.7429
# Epoch 23/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.6525 - accuracy: 0.7691 - val_loss: 0.8383 - val_accuracy: 0.7330
# Epoch 24/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.6403 - accuracy: 0.7736 - val_loss: 0.8252 - val_accuracy: 0.7469
# Epoch 25/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.6313 - accuracy: 0.7783 - val_loss: 0.8317 - val_accuracy: 0.7459
# Epoch 26/100
# 50000/50000 [==============================] - 33s 666us/step - loss: 0.6221 - accuracy: 0.7778 - val_loss: 0.8522 - val_accuracy: 0.7195
# Epoch 27/100
# 50000/50000 [==============================] - 33s 667us/step - loss: 0.6153 - accuracy: 0.7829 - val_loss: 0.8335 - val_accuracy: 0.7403
# Epoch 28/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.6049 - accuracy: 0.7860 - val_loss: 0.7753 - val_accuracy: 0.7614
# Epoch 29/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.5911 - accuracy: 0.7933 - val_loss: 0.8112 - val_accuracy: 0.7459
# Epoch 30/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.5812 - accuracy: 0.7942 - val_loss: 0.7863 - val_accuracy: 0.7617
# Epoch 31/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.5782 - accuracy: 0.7956 - val_loss: 0.7770 - val_accuracy: 0.7538
# Epoch 32/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5734 - accuracy: 0.7986 - val_loss: 0.7665 - val_accuracy: 0.7626
# Epoch 33/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.5678 - accuracy: 0.8002 - val_loss: 0.7759 - val_accuracy: 0.7542
# Epoch 34/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5566 - accuracy: 0.8035 - val_loss: 0.7595 - val_accuracy: 0.7682
# Epoch 35/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.5508 - accuracy: 0.8068 - val_loss: 0.7926 - val_accuracy: 0.7421
# Epoch 36/100
# 50000/50000 [==============================] - 34s 670us/step - loss: 0.5411 - accuracy: 0.8084 - val_loss: 0.7221 - val_accuracy: 0.7809
# Epoch 37/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.5408 - accuracy: 0.8079 - val_loss: 0.7271 - val_accuracy: 0.7753
# Epoch 38/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5332 - accuracy: 0.8105 - val_loss: 0.7193 - val_accuracy: 0.7810
# Epoch 39/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5279 - accuracy: 0.8158 - val_loss: 0.7282 - val_accuracy: 0.7704
# Epoch 40/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.5201 - accuracy: 0.8171 - val_loss: 0.7252 - val_accuracy: 0.7677
# Epoch 41/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.5165 - accuracy: 0.8181 - val_loss: 0.7068 - val_accuracy: 0.7792
# Epoch 42/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5109 - accuracy: 0.8201 - val_loss: 0.7269 - val_accuracy: 0.7759
# Epoch 43/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.5040 - accuracy: 0.8237 - val_loss: 0.7213 - val_accuracy: 0.7735
# Epoch 44/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.5056 - accuracy: 0.8223 - val_loss: 0.7074 - val_accuracy: 0.7801
# Epoch 45/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4998 - accuracy: 0.8250 - val_loss: 0.7317 - val_accuracy: 0.7741
# Epoch 46/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4930 - accuracy: 0.8271 - val_loss: 0.6617 - val_accuracy: 0.7989
# Epoch 47/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4868 - accuracy: 0.8280 - val_loss: 0.6937 - val_accuracy: 0.7819
# Epoch 48/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4863 - accuracy: 0.8280 - val_loss: 0.6887 - val_accuracy: 0.7818
# Epoch 49/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4838 - accuracy: 0.8293 - val_loss: 0.6859 - val_accuracy: 0.7847
# Epoch 50/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4788 - accuracy: 0.8316 - val_loss: 0.7224 - val_accuracy: 0.7657
# Epoch 51/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4743 - accuracy: 0.8325 - val_loss: 0.6868 - val_accuracy: 0.7824
# Epoch 52/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4685 - accuracy: 0.8345 - val_loss: 0.6835 - val_accuracy: 0.7790
# Epoch 53/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4693 - accuracy: 0.8343 - val_loss: 0.6870 - val_accuracy: 0.7855
# Epoch 54/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4626 - accuracy: 0.8376 - val_loss: 0.6875 - val_accuracy: 0.7821
# Epoch 55/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4640 - accuracy: 0.8379 - val_loss: 0.6795 - val_accuracy: 0.7832
# Epoch 56/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4569 - accuracy: 0.8380 - val_loss: 0.6508 - val_accuracy: 0.7971
# Epoch 57/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4575 - accuracy: 0.8385 - val_loss: 0.6658 - val_accuracy: 0.7898
# Epoch 58/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4493 - accuracy: 0.8420 - val_loss: 0.6579 - val_accuracy: 0.7977
# Epoch 59/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4495 - accuracy: 0.8401 - val_loss: 0.6441 - val_accuracy: 0.8033
# Epoch 60/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4503 - accuracy: 0.8407 - val_loss: 0.6529 - val_accuracy: 0.7952
# Epoch 61/100
# 50000/50000 [==============================] - 34s 676us/step - loss: 0.4426 - accuracy: 0.8430 - val_loss: 0.6518 - val_accuracy: 0.7992
# Epoch 62/100
# 50000/50000 [==============================] - 34s 678us/step - loss: 0.4406 - accuracy: 0.8434 - val_loss: 0.6691 - val_accuracy: 0.7820
# Epoch 63/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4384 - accuracy: 0.8439 - val_loss: 0.6411 - val_accuracy: 0.7980
# Epoch 64/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4358 - accuracy: 0.8436 - val_loss: 0.6384 - val_accuracy: 0.7975
# Epoch 65/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4331 - accuracy: 0.8481 - val_loss: 0.6347 - val_accuracy: 0.8038
# Epoch 66/100
# 50000/50000 [==============================] - 34s 676us/step - loss: 0.4345 - accuracy: 0.8479 - val_loss: 0.6434 - val_accuracy: 0.7962
# Epoch 67/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4257 - accuracy: 0.8510 - val_loss: 0.6206 - val_accuracy: 0.8058
# Epoch 68/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4264 - accuracy: 0.8490 - val_loss: 0.6321 - val_accuracy: 0.8009
# Epoch 69/100
# 50000/50000 [==============================] - 34s 676us/step - loss: 0.4247 - accuracy: 0.8492 - val_loss: 0.6267 - val_accuracy: 0.8034
# Epoch 70/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4214 - accuracy: 0.8497 - val_loss: 0.6424 - val_accuracy: 0.7982
# Epoch 71/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4227 - accuracy: 0.8518 - val_loss: 0.6502 - val_accuracy: 0.7888
# Epoch 72/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.4139 - accuracy: 0.8539 - val_loss: 0.6228 - val_accuracy: 0.8057
# Epoch 73/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4157 - accuracy: 0.8519 - val_loss: 0.6179 - val_accuracy: 0.8034
# Epoch 74/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4114 - accuracy: 0.8542 - val_loss: 0.6100 - val_accuracy: 0.8054
# Epoch 75/100
# 50000/50000 [==============================] - 34s 673us/step - loss: 0.4109 - accuracy: 0.8558 - val_loss: 0.6243 - val_accuracy: 0.8025
# Epoch 76/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4100 - accuracy: 0.8536 - val_loss: 0.6475 - val_accuracy: 0.7928
# Epoch 77/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.4100 - accuracy: 0.8561 - val_loss: 0.6323 - val_accuracy: 0.8067
# Epoch 78/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4077 - accuracy: 0.8544 - val_loss: 0.6726 - val_accuracy: 0.7759
# Epoch 79/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.4051 - accuracy: 0.8563 - val_loss: 0.5910 - val_accuracy: 0.8138
# Epoch 80/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.4019 - accuracy: 0.8575 - val_loss: 0.6293 - val_accuracy: 0.7976
# Epoch 81/100
# 50000/50000 [==============================] - 34s 670us/step - loss: 0.4030 - accuracy: 0.8582 - val_loss: 0.6252 - val_accuracy: 0.8008
# Epoch 82/100
# 50000/50000 [==============================] - 33s 666us/step - loss: 0.3983 - accuracy: 0.8597 - val_loss: 0.6178 - val_accuracy: 0.8000
# Epoch 83/100
# 50000/50000 [==============================] - 33s 668us/step - loss: 0.3958 - accuracy: 0.8605 - val_loss: 0.6019 - val_accuracy: 0.8099
# Epoch 84/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.3963 - accuracy: 0.8602 - val_loss: 0.6138 - val_accuracy: 0.8075
# Epoch 85/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.3923 - accuracy: 0.8612 - val_loss: 0.6050 - val_accuracy: 0.8081
# Epoch 86/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3944 - accuracy: 0.8608 - val_loss: 0.6026 - val_accuracy: 0.8123
# Epoch 87/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.3885 - accuracy: 0.8627 - val_loss: 0.5838 - val_accuracy: 0.8189
# Epoch 88/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.3930 - accuracy: 0.8614 - val_loss: 0.5931 - val_accuracy: 0.8138
# Epoch 89/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3899 - accuracy: 0.8618 - val_loss: 0.5930 - val_accuracy: 0.8182
# Epoch 90/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3871 - accuracy: 0.8621 - val_loss: 0.6101 - val_accuracy: 0.8074
# Epoch 91/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.3863 - accuracy: 0.8621 - val_loss: 0.6246 - val_accuracy: 0.8012
# Epoch 92/100
# 50000/50000 [==============================] - 34s 672us/step - loss: 0.3817 - accuracy: 0.8648 - val_loss: 0.6317 - val_accuracy: 0.7971
# Epoch 93/100
# 50000/50000 [==============================] - 34s 674us/step - loss: 0.3802 - accuracy: 0.8643 - val_loss: 0.5930 - val_accuracy: 0.8118
# Epoch 94/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3833 - accuracy: 0.8643 - val_loss: 0.6188 - val_accuracy: 0.8030
# Epoch 95/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3827 - accuracy: 0.8645 - val_loss: 0.5906 - val_accuracy: 0.8133
# Epoch 96/100
# 50000/50000 [==============================] - 34s 671us/step - loss: 0.3781 - accuracy: 0.8651 - val_loss: 0.5975 - val_accuracy: 0.8125
# Epoch 97/100
# 50000/50000 [==============================] - 33s 669us/step - loss: 0.3769 - accuracy: 0.8675 - val_loss: 0.6094 - val_accuracy: 0.8046
# Epoch 98/100
# 50000/50000 [==============================] - 33s 670us/step - loss: 0.3776 - accuracy: 0.8649 - val_loss: 0.6187 - val_accuracy: 0.8009
# Epoch 99/100
# 50000/50000 [==============================] - 34s 670us/step - loss: 0.3781 - accuracy: 0.8657 - val_loss: 0.6208 - val_accuracy: 0.7992
# Epoch 100/100
# 50000/50000 [==============================] - 34s 670us/step - loss: 0.3731 - accuracy: 0.8686 - val_loss: 0.5815 - val_accuracy: 0.8199
# Accuracy: 81.99%
