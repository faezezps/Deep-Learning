# %% [markdown]
# # Dependencies

# %%
# !python -c 'import tensorflow; print(tensorflow.__version__)'
# Out:
# 2020-07-20 14:22:31.808763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2.2.0

# %%
# !pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 41kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.12.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.30.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 51.7MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.5)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 44.7MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15) (49.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=ecdfbce045c78402129dfe35e44e926563bb23881b87dd322f6533680d942865
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, gast, tensorflow
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import sys
import numpy as np
from keras import regularizers, constraints
from keras import backend as K
import tensorflow as tf

# %% [markdown]
# # GAN

# %%
class GAN():
  def __init__(self):
    self.img_rows = 28
    self.img_cols = 28
    self.channels = 1
    self.img_shape = (self.img_rows, self.img_cols, self.channels)
    self.latent_dim = 128
    optimizer = Adam(0.0002, 0.5) 
    self.discriminator = self.build_discriminator()
    self.discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
        
    self.generator = self.build_generator()

#-------------------------------------------------------------------------
    z = Input(shape=(self.latent_dim,))
    print('--------------------------------')
    print('This is z :' , z)
    print('This is z.shape :' , z.shape)
        

#--------------------------------------------------------------------------
    img = self.generator(z)
    print('--------------------------------')
    print('Image shape: ', img.shape)

    self.discriminator.trainable = False

#-----------------------------------------------------------------------------
    validity = self.discriminator(img)
    print('--------------------------------')
    print('Validity: ', validity)
    print('--------------------------------')
    print('Type of validity:', type(validity))

    #self.ditance = tf.convert_to_tensor(np.linalg.norm(img))
    #self.combined = Model((z,distance), (validity, distance))
    
    self.combined = Model(z, (distance ,validity))
    self.combined.compile(loss='binary_crossentropy', optimizer=optimizer)
    
    
  def build_generator(self):
    model = Sequential()
    model.add(Dense(256, input_dim=self.latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(np.prod(self.img_shape), activation='tanh'))
    model.add(Reshape(self.img_shape))
    model.summary()
    noise = Input(shape=(self.latent_dim,))
    img = model(noise)
    return Model(noise, img)
        
  def build_discriminator(self):
    model = Sequential()
    model.add(Flatten(input_shape=self.img_shape))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    
#-------------------------------------------------------------------------------------
 #   model.add(MinibatchDiscrimination(4, 4, input_dim = (256,)))
 #   model.add(Reshape((16,16)))
 #   model.add(Flatten())
#------------------------------------------------------------------------------------

    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    img = Input(shape=self.img_shape)
    validity = model(img)
    return Model(img, validity)


  #def train(self, epochs, batch_size=128, sample_interval=60):
  def train(self, epochs, batch_size, sample_interval):
    (X_train, _), (_, _) = mnist.load_data()
    
#-------------------------------------------------------------------
    #print('x train [0]:', X_train[0] , ' its shape:', X_train[0].shape) ---------> 28*28

    X_train = X_train / 127.5 - 1.
    X_train = np.expand_dims(X_train, axis=3)
    #print('new x train[0] :', X_train[0] , ' its shape:', X_train[0].shape) ------> 28*28*1
      
      
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    print('--------------------------------')
    print('valid.shape inside training:', valid.shape)
    print('--------------------------------')
    print('fake.shape inside training:', fake.shape)

    for epoch in range(epochs):
      #-------------------------------------------------------------------------
      idx = np.random.randint(0, X_train.shape[0], batch_size)
      print('--------------------------------')
      print("this is idx.shape: ", idx.shape)

      imgs = X_train[idx]
      print('--------------------------------')
      #print('imgs.shape:', imgs.shape)
        
      noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
      #print('noise:', noise)
      gen_imgs = self.generator.predict(noise)
      #print('gen_imgs', gen_imgs)
      #print('hello')
          
      #-------------------------------------------------------------------------------------------
      d_loss_real = self.discriminator.train_on_batch(imgs, valid)
      print('--------------------------------')
      print('d loss real', d_loss_real)

      d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)
      print('--------------------------------')
      print('d loss fake', d_loss_fake)

      d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
      print('--------------------------------')
      print(' d_ loss ' , d_loss)
          
# ------------------------------------------------------------------------------------------------
 #its shape --> zeros
      #mean_samples =   np.zeroes((1, self.latent_dim))
      #for i in range(1, batch_size):
      #  other_samples_noise = np.random.normal(0, 1, (1, self.latent_dim))
      #  mean_samples = mean_samples + noise
      #mean_samples = mean_samples/(batch_size-1)

      #first_sample_noise = noise = np.random.normal(0, 1, (1, self.latent_dim))

      #g_discrimination = 


# --------------------------------------------------------------------------------------------------
 #its shape --> zeros (initialize)
      #mean_samples =   np.zeroes((1, self.latent_dim))
      #max_discrimination = vector
     
      #other_samples_noise = np.random.normal(0, 1, ((batch_size -1), self.latent_dim))
      #mean_samples = other_samples_noise #(jam besham ruye sutun)
      #mean_samples = mean_samples/(batch_size-1) #taghsim beshan be tedad vas miyangin gereftan
        
      #first_sample_noise = np.random.normal(0, 1, (1, self.latent_dim))
      #discrimination = first_sample_noise - mean_samples

      #fake_generated_sample_1 = self.generator.predict(first_sample_noise)
      #fake_generated_sample_2 = self.generator.predict(discrimination)

      #use mean squer for calculating the distance
      #discrimination = fake_generated_sample_1 - fake_generated_sample_2

      #g_discrimination = 
# ------------------------------------------------------------------------------------------------

      noise = np.random.normal(0, 1, (batch_size, self.latent_dim))

# ------------------------------------------------------------------------------------------------
      fake_images = self.generator.predict(noise)
      #g_loss_discrimination = 1/(np.linalg.norm(fake_images))
      g_loss_discrimination = 1/(np.linalg.norm(fake_images))
      
      
      #real_data_discrimination = 1/(np.linalg.norm(imgs))
      #print('real data discrimination:',  real_data_discrimination , " vs generated data discrimination: ", g_loss_discrimination)

      sigma = 0.8
      new_noise = (noise + g_loss_discrimination)/sigma**2


      #print('first loss discrimination : ', g_loss_discrimination)

      #while g_loss_discrimination < 0.001:
      #  noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
      #  fake_images = self.generator.predict(noise)
      #  g_loss_discrimination = 1/(np.linalg.norm(fake_images))

      #print('loss discrimination after while :', g_loss_discrimination)
      
      # generator train on batch (generator with two out put)
# ------------------------------------------------------------------------------------------------

      #g_loss = self.combined.train_on_batch(noise, g_loss_discrimination , valid)

      #g_loss = self.combined.train_on_batch((noise, g_loss_discrimination ) , (valid, g_loss_discrimination))
      
      g_loss = self.combined.train_on_batch(new_noise, valid)
      

# ------------------------------------------------------------------------------------------------
      #g_loss_new = g_loss * g_loss_discrimination
      #print('g_loss_new:' , g_loss_new)
# ------------------------------------------------------------------------------------------------


      print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
      if epoch % sample_interval == 0:
        self.sample_images(epoch)

  def sample_images(self, epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, self.latent_dim))
    gen_imgs = self.generator.predict(noise)
    gen_imgs = 0.5 * gen_imgs + 0.5
    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
      for j in range(c):
        axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
        axs[i,j].axis('off')
        cnt += 1
      #fig.savefig("images/%d.png" % epoch)
      plt.close()

# %%
if __name__ == '__main__':
    gan = GAN()
    gan.train(epochs=10000, batch_size=128, sample_interval=1000)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 512)               401920
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 533,505
# Trainable params: 533,505
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_47 (Dense)             (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_48 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_49 (Dense)             (None, 784)               803600
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,500,688
# Trainable params: 1,497,104
# Non-trainable params: 3,584
# _________________________________________________________________
# --------------------------------
# This is z : Tensor("input_21:0", shape=(?, 128), dtype=float32)
# This is z.shape : (?, 128)
# --------------------------------
# Image shape:  (?, 28, 28, 1)
# --------------------------------
# Validity:  Tensor("model_14/sequential_13/dense_45/Sigmoid:0", shape=(?, 1), dtype=float32)
# --------------------------------
# Type of validity: <class 'tensorflow.python.framework.ops.Tensor'>
# --------------------------------
# valid.shape inside training: (128, 1)
# --------------------------------
# fake.shape inside training: (128, 1)
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# --------------------------------
# d loss real [0.8852261, 0.25]
# --------------------------------
# d loss fake [0.6840894, 0.5625]
# --------------------------------
#  d_ loss  [0.7846577 0.40625  ]
# 0 [D loss: 0.784658, acc.: 40.62%] [G loss: 0.702053]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.09943694, 1.0]
# --------------------------------
# d loss fake [0.672032, 0.59375]
# --------------------------------
#  d_ loss  [0.38573447 0.796875  ]
# 1 [D loss: 0.385734, acc.: 79.69%] [G loss: 0.709230]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.029927103, 1.0]
# --------------------------------
# d loss fake [0.69095993, 0.53125]
# --------------------------------
#  d_ loss  [0.3604435 0.765625 ]
# 2 [D loss: 0.360444, acc.: 76.56%] [G loss: 0.738562]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.020527776, 1.0]
# --------------------------------
# d loss fake [0.7011173, 0.5078125]
# --------------------------------
#  d_ loss  [0.36082253 0.75390625]
# 3 [D loss: 0.360823, acc.: 75.39%] [G loss: 0.815039]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.014475744, 1.0]
# --------------------------------
# d loss fake [0.6909023, 0.46875]
# --------------------------------
#  d_ loss  [0.35268903 0.734375  ]
# 4 [D loss: 0.352689, acc.: 73.44%] [G loss: 0.847502]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.01664208, 1.0]
# --------------------------------
# d loss fake [0.6841384, 0.5703125]
# --------------------------------
#  d_ loss  [0.35039026 0.78515625]
# 5 [D loss: 0.350390, acc.: 78.52%] [G loss: 0.943409]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.016228069, 1.0]
# --------------------------------
# d loss fake [0.5765202, 0.8984375]
# --------------------------------
#  d_ loss  [0.29637414 0.94921875]
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Streaming output truncated to the last 5000 lines.
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6228999, 0.6484375]
# --------------------------------
# d loss fake [0.67095226, 0.578125]
# --------------------------------
#  d_ loss  [0.64692605 0.61328125]
# 9500 [D loss: 0.646926, acc.: 61.33%] [G loss: 0.849486]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63360816, 0.703125]
# --------------------------------
# d loss fake [0.66078687, 0.5703125]
# --------------------------------
#  d_ loss  [0.6471975  0.63671875]
# 9501 [D loss: 0.647197, acc.: 63.67%] [G loss: 0.849435]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.57775325, 0.7109375]
# --------------------------------
# d loss fake [0.72542214, 0.4765625]
# --------------------------------
#  d_ loss  [0.6515877 0.59375  ]
# 9502 [D loss: 0.651588, acc.: 59.38%] [G loss: 0.896426]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6408285, 0.625]
# --------------------------------
# d loss fake [0.6745013, 0.5859375]
# --------------------------------
#  d_ loss  [0.6576649  0.60546875]
# 9503 [D loss: 0.657665, acc.: 60.55%] [G loss: 0.899749]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6932793, 0.5390625]
# --------------------------------
# d loss fake [0.65069216, 0.6484375]
# --------------------------------
#  d_ loss  [0.67198575 0.59375   ]
# 9504 [D loss: 0.671986, acc.: 59.38%] [G loss: 0.844851]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.66298, 0.546875]
# --------------------------------
# d loss fake [0.6746754, 0.5390625]
# --------------------------------
#  d_ loss  [0.6688277  0.54296875]
# 9505 [D loss: 0.668828, acc.: 54.30%] [G loss: 0.897421]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6925185, 0.5]
# --------------------------------
# d loss fake [0.5886629, 0.75]
# --------------------------------
#  d_ loss  [0.64059067 0.625     ]
# 9506 [D loss: 0.640591, acc.: 62.50%] [G loss: 0.830983]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6450256, 0.578125]
# --------------------------------
# d loss fake [0.6960952, 0.53125]
# --------------------------------
#  d_ loss  [0.6705604 0.5546875]
# 9507 [D loss: 0.670560, acc.: 55.47%] [G loss: 0.872560]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62166, 0.6484375]
# --------------------------------
# d loss fake [0.6381983, 0.5859375]
# --------------------------------
#  d_ loss  [0.6299292 0.6171875]
# 9508 [D loss: 0.629929, acc.: 61.72%] [G loss: 0.863029]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6075192, 0.703125]
# --------------------------------
# d loss fake [0.65379435, 0.6015625]
# --------------------------------
#  d_ loss  [0.6306568  0.65234375]
# 9509 [D loss: 0.630657, acc.: 65.23%] [G loss: 0.829047]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60894096, 0.6796875]
# --------------------------------
# d loss fake [0.64126813, 0.640625]
# --------------------------------
#  d_ loss  [0.62510455 0.66015625]
# 9510 [D loss: 0.625105, acc.: 66.02%] [G loss: 0.809029]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6205938, 0.6953125]
# --------------------------------
# d loss fake [0.66788787, 0.609375]
# --------------------------------
#  d_ loss  [0.64424086 0.65234375]
# 9511 [D loss: 0.644241, acc.: 65.23%] [G loss: 0.858208]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6345953, 0.6484375]
# --------------------------------
# d loss fake [0.64021224, 0.6171875]
# --------------------------------
#  d_ loss  [0.6374037 0.6328125]
# 9512 [D loss: 0.637404, acc.: 63.28%] [G loss: 0.838141]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6430018, 0.625]
# --------------------------------
# d loss fake [0.6421313, 0.640625]
# --------------------------------
#  d_ loss  [0.64256656 0.6328125 ]
# 9513 [D loss: 0.642567, acc.: 63.28%] [G loss: 0.856770]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6447412, 0.6328125]
# --------------------------------
# d loss fake [0.63269514, 0.6484375]
# --------------------------------
#  d_ loss  [0.6387181 0.640625 ]
# 9514 [D loss: 0.638718, acc.: 64.06%] [G loss: 0.834612]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.59535587, 0.6953125]
# --------------------------------
# d loss fake [0.64252627, 0.625]
# --------------------------------
#  d_ loss  [0.61894107 0.66015625]
# 9515 [D loss: 0.618941, acc.: 66.02%] [G loss: 0.812505]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6516706, 0.6484375]
# --------------------------------
# d loss fake [0.66085595, 0.609375]
# --------------------------------
#  d_ loss  [0.65626323 0.62890625]
# 9516 [D loss: 0.656263, acc.: 62.89%] [G loss: 0.818659]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6032169, 0.6875]
# --------------------------------
# d loss fake [0.6594556, 0.578125]
# --------------------------------
#  d_ loss  [0.6313362 0.6328125]
# 9517 [D loss: 0.631336, acc.: 63.28%] [G loss: 0.836225]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63374794, 0.671875]
# --------------------------------
# d loss fake [0.6600921, 0.6015625]
# --------------------------------
#  d_ loss  [0.64692    0.63671875]
# 9518 [D loss: 0.646920, acc.: 63.67%] [G loss: 0.860279]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62925804, 0.671875]
# --------------------------------
# d loss fake [0.6699204, 0.640625]
# --------------------------------
#  d_ loss  [0.6495892 0.65625  ]
# 9519 [D loss: 0.649589, acc.: 65.62%] [G loss: 0.827575]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.645463, 0.6328125]
# --------------------------------
# d loss fake [0.69327146, 0.53125]
# --------------------------------
#  d_ loss  [0.6693672  0.58203125]
# 9520 [D loss: 0.669367, acc.: 58.20%] [G loss: 0.818873]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6123436, 0.6171875]
# --------------------------------
# d loss fake [0.6412113, 0.7109375]
# --------------------------------
#  d_ loss  [0.6267774 0.6640625]
# 9521 [D loss: 0.626777, acc.: 66.41%] [G loss: 0.822274]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6550234, 0.5703125]
# --------------------------------
# d loss fake [0.63466316, 0.6171875]
# --------------------------------
#  d_ loss  [0.6448433 0.59375  ]
# 9522 [D loss: 0.644843, acc.: 59.38%] [G loss: 0.798301]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6263299, 0.6875]
# --------------------------------
# d loss fake [0.6412023, 0.6171875]
# --------------------------------
#  d_ loss  [0.63376606 0.65234375]
# 9523 [D loss: 0.633766, acc.: 65.23%] [G loss: 0.817850]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6743971, 0.609375]
# --------------------------------
# d loss fake [0.62443346, 0.640625]
# --------------------------------
#  d_ loss  [0.64941525 0.625     ]
# 9524 [D loss: 0.649415, acc.: 62.50%] [G loss: 0.816970]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5834172, 0.6796875]
# --------------------------------
# d loss fake [0.61821437, 0.6484375]
# --------------------------------
#  d_ loss  [0.6008158 0.6640625]
# 9525 [D loss: 0.600816, acc.: 66.41%] [G loss: 0.837002]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6763865, 0.5546875]
# --------------------------------
# d loss fake [0.6345811, 0.65625]
# --------------------------------
#  d_ loss  [0.6554838  0.60546875]
# 9526 [D loss: 0.655484, acc.: 60.55%] [G loss: 0.811933]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62067634, 0.6640625]
# --------------------------------
# d loss fake [0.69145936, 0.5703125]
# --------------------------------
#  d_ loss  [0.65606785 0.6171875 ]
# 9527 [D loss: 0.656068, acc.: 61.72%] [G loss: 0.846601]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6538402, 0.6328125]
# --------------------------------
# d loss fake [0.67141414, 0.5546875]
# --------------------------------
#  d_ loss  [0.66262716 0.59375   ]
# 9528 [D loss: 0.662627, acc.: 59.38%] [G loss: 0.832295]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6080165, 0.6953125]
# --------------------------------
# d loss fake [0.6709163, 0.5625]
# --------------------------------
#  d_ loss  [0.6394664  0.62890625]
# 9529 [D loss: 0.639466, acc.: 62.89%] [G loss: 0.848074]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60950017, 0.6640625]
# --------------------------------
# d loss fake [0.6483542, 0.6484375]
# --------------------------------
#  d_ loss  [0.6289272 0.65625  ]
# 9530 [D loss: 0.628927, acc.: 65.62%] [G loss: 0.893303]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6461119, 0.609375]
# --------------------------------
# d loss fake [0.6397982, 0.65625]
# --------------------------------
#  d_ loss  [0.64295506 0.6328125 ]
# 9531 [D loss: 0.642955, acc.: 63.28%] [G loss: 0.884936]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63246787, 0.6484375]
# --------------------------------
# d loss fake [0.6671642, 0.5546875]
# --------------------------------
#  d_ loss  [0.64981604 0.6015625 ]
# 9532 [D loss: 0.649816, acc.: 60.16%] [G loss: 0.879862]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62696564, 0.671875]
# --------------------------------
# d loss fake [0.63493156, 0.59375]
# --------------------------------
#  d_ loss  [0.6309486 0.6328125]
# 9533 [D loss: 0.630949, acc.: 63.28%] [G loss: 0.948338]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62604266, 0.6484375]
# --------------------------------
# d loss fake [0.674984, 0.6484375]
# --------------------------------
#  d_ loss  [0.6505133 0.6484375]
# 9534 [D loss: 0.650513, acc.: 64.84%] [G loss: 0.890677]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62630856, 0.6171875]
# --------------------------------
# d loss fake [0.63735354, 0.6328125]
# --------------------------------
#  d_ loss  [0.63183105 0.625     ]
# 9535 [D loss: 0.631831, acc.: 62.50%] [G loss: 0.917904]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6382865, 0.640625]
# --------------------------------
# d loss fake [0.60579944, 0.671875]
# --------------------------------
#  d_ loss  [0.62204295 0.65625   ]
# 9536 [D loss: 0.622043, acc.: 65.62%] [G loss: 0.842851]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.64973974, 0.59375]
# --------------------------------
# d loss fake [0.63154733, 0.65625]
# --------------------------------
#  d_ loss  [0.64064354 0.625     ]
# 9537 [D loss: 0.640644, acc.: 62.50%] [G loss: 0.831961]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6219973, 0.6953125]
# --------------------------------
# d loss fake [0.68083936, 0.5703125]
# --------------------------------
#  d_ loss  [0.6514183 0.6328125]
# 9538 [D loss: 0.651418, acc.: 63.28%] [G loss: 0.854527]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6292033, 0.59375]
# --------------------------------
# d loss fake [0.6624154, 0.5625]
# --------------------------------
#  d_ loss  [0.64580935 0.578125  ]
# 9539 [D loss: 0.645809, acc.: 57.81%] [G loss: 0.842885]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60736537, 0.703125]
# --------------------------------
# d loss fake [0.6009763, 0.640625]
# --------------------------------
#  d_ loss  [0.6041708 0.671875 ]
# 9540 [D loss: 0.604171, acc.: 67.19%] [G loss: 0.787102]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6335806, 0.609375]
# --------------------------------
# d loss fake [0.6521115, 0.5625]
# --------------------------------
#  d_ loss  [0.64284605 0.5859375 ]
# 9541 [D loss: 0.642846, acc.: 58.59%] [G loss: 0.837691]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.59938145, 0.6640625]
# --------------------------------
# d loss fake [0.65671045, 0.625]
# --------------------------------
#  d_ loss  [0.6280459  0.64453125]
# 9542 [D loss: 0.628046, acc.: 64.45%] [G loss: 0.834979]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6232474, 0.6171875]
# --------------------------------
# d loss fake [0.66254354, 0.578125]
# --------------------------------
#  d_ loss  [0.64289546 0.59765625]
# 9543 [D loss: 0.642895, acc.: 59.77%] [G loss: 0.805290]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6690446, 0.59375]
# --------------------------------
# d loss fake [0.6944009, 0.5703125]
# --------------------------------
#  d_ loss  [0.68172276 0.58203125]
# 9544 [D loss: 0.681723, acc.: 58.20%] [G loss: 0.814761]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.616965, 0.6171875]
# --------------------------------
# d loss fake [0.6479834, 0.6171875]
# --------------------------------
#  d_ loss  [0.6324742 0.6171875]
# 9545 [D loss: 0.632474, acc.: 61.72%] [G loss: 0.809898]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60233134, 0.71875]
# --------------------------------
# d loss fake [0.6485521, 0.609375]
# --------------------------------
#  d_ loss  [0.62544173 0.6640625 ]
# 9546 [D loss: 0.625442, acc.: 66.41%] [G loss: 0.894109]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6690805, 0.5859375]
# --------------------------------
# d loss fake [0.6098259, 0.6953125]
# --------------------------------
#  d_ loss  [0.6394532 0.640625 ]
# 9547 [D loss: 0.639453, acc.: 64.06%] [G loss: 0.863933]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.67000115, 0.5859375]
# --------------------------------
# d loss fake [0.642547, 0.609375]
# --------------------------------
#  d_ loss  [0.6562741  0.59765625]
# 9548 [D loss: 0.656274, acc.: 59.77%] [G loss: 0.819565]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5862261, 0.6796875]
# --------------------------------
# d loss fake [0.69793665, 0.578125]
# --------------------------------
#  d_ loss  [0.6420814  0.62890625]
# 9549 [D loss: 0.642081, acc.: 62.89%] [G loss: 0.836221]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6135433, 0.6796875]
# --------------------------------
# d loss fake [0.6858255, 0.5703125]
# --------------------------------
#  d_ loss  [0.6496844 0.625    ]
# 9550 [D loss: 0.649684, acc.: 62.50%] [G loss: 0.857449]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6012137, 0.6796875]
# --------------------------------
# d loss fake [0.6821254, 0.546875]
# --------------------------------
#  d_ loss  [0.6416695  0.61328125]
# 9551 [D loss: 0.641670, acc.: 61.33%] [G loss: 0.858285]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.64817464, 0.640625]
# --------------------------------
# d loss fake [0.6089265, 0.6796875]
# --------------------------------
#  d_ loss  [0.6285505  0.66015625]
# 9552 [D loss: 0.628551, acc.: 66.02%] [G loss: 0.888529]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6824634, 0.59375]
# --------------------------------
# d loss fake [0.65642273, 0.6328125]
# --------------------------------
#  d_ loss  [0.6694431  0.61328125]
# 9553 [D loss: 0.669443, acc.: 61.33%] [G loss: 0.897195]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6353338, 0.6875]
# --------------------------------
# d loss fake [0.6192305, 0.6484375]
# --------------------------------
#  d_ loss  [0.62728214 0.66796875]
# 9554 [D loss: 0.627282, acc.: 66.80%] [G loss: 0.880431]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6563189, 0.5703125]
# --------------------------------
# d loss fake [0.6182128, 0.703125]
# --------------------------------
#  d_ loss  [0.63726586 0.63671875]
# 9555 [D loss: 0.637266, acc.: 63.67%] [G loss: 0.849156]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5432367, 0.7890625]
# --------------------------------
# d loss fake [0.6654036, 0.5234375]
# --------------------------------
#  d_ loss  [0.60432017 0.65625   ]
# 9556 [D loss: 0.604320, acc.: 65.62%] [G loss: 0.834854]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63348144, 0.6484375]
# --------------------------------
# d loss fake [0.6674439, 0.6015625]
# --------------------------------
#  d_ loss  [0.6504626 0.625    ]
# 9557 [D loss: 0.650463, acc.: 62.50%] [G loss: 0.877484]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.64744246, 0.6171875]
# --------------------------------
# d loss fake [0.64295197, 0.65625]
# --------------------------------
#  d_ loss  [0.6451972  0.63671875]
# 9558 [D loss: 0.645197, acc.: 63.67%] [G loss: 0.807799]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.66606337, 0.5859375]
# --------------------------------
# d loss fake [0.61220104, 0.6875]
# --------------------------------
#  d_ loss  [0.6391322  0.63671875]
# 9559 [D loss: 0.639132, acc.: 63.67%] [G loss: 0.814294]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62839043, 0.6796875]
# --------------------------------
# d loss fake [0.6863041, 0.546875]
# --------------------------------
#  d_ loss  [0.65734726 0.61328125]
# 9560 [D loss: 0.657347, acc.: 61.33%] [G loss: 0.823000]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60112625, 0.6875]
# --------------------------------
# d loss fake [0.67215604, 0.609375]
# --------------------------------
#  d_ loss  [0.63664114 0.6484375 ]
# 9561 [D loss: 0.636641, acc.: 64.84%] [G loss: 0.852576]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60571367, 0.703125]
# --------------------------------
# d loss fake [0.5995674, 0.7109375]
# --------------------------------
#  d_ loss  [0.6026405  0.70703125]
# 9562 [D loss: 0.602641, acc.: 70.70%] [G loss: 0.829836]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62160397, 0.625]
# --------------------------------
# d loss fake [0.63028353, 0.6640625]
# --------------------------------
#  d_ loss  [0.6259438  0.64453125]
# 9563 [D loss: 0.625944, acc.: 64.45%] [G loss: 0.807637]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60252166, 0.640625]
# --------------------------------
# d loss fake [0.67903537, 0.5703125]
# --------------------------------
#  d_ loss  [0.64077854 0.60546875]
# 9564 [D loss: 0.640779, acc.: 60.55%] [G loss: 0.821921]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6391583, 0.6328125]
# --------------------------------
# d loss fake [0.66041046, 0.59375]
# --------------------------------
#  d_ loss  [0.6497844  0.61328125]
# 9565 [D loss: 0.649784, acc.: 61.33%] [G loss: 0.839372]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.68301964, 0.5078125]
# --------------------------------
# d loss fake [0.64449, 0.59375]
# --------------------------------
#  d_ loss  [0.6637548  0.55078125]
# 9566 [D loss: 0.663755, acc.: 55.08%] [G loss: 0.807481]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60203207, 0.6875]
# --------------------------------
# d loss fake [0.62939805, 0.671875]
# --------------------------------
#  d_ loss  [0.615715  0.6796875]
# 9567 [D loss: 0.615715, acc.: 67.97%] [G loss: 0.830810]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63343364, 0.65625]
# --------------------------------
# d loss fake [0.6625302, 0.671875]
# --------------------------------
#  d_ loss  [0.6479819 0.6640625]
# 9568 [D loss: 0.647982, acc.: 66.41%] [G loss: 0.852798]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6401495, 0.6015625]
# --------------------------------
# d loss fake [0.5983707, 0.703125]
# --------------------------------
#  d_ loss  [0.6192601  0.65234375]
# 9569 [D loss: 0.619260, acc.: 65.23%] [G loss: 0.824094]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6561015, 0.625]
# --------------------------------
# d loss fake [0.6575029, 0.5546875]
# --------------------------------
#  d_ loss  [0.6568022  0.58984375]
# 9570 [D loss: 0.656802, acc.: 58.98%] [G loss: 0.804736]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6262458, 0.640625]
# --------------------------------
# d loss fake [0.6244975, 0.6640625]
# --------------------------------
#  d_ loss  [0.62537163 0.65234375]
# 9571 [D loss: 0.625372, acc.: 65.23%] [G loss: 0.805485]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.57583237, 0.671875]
# --------------------------------
# d loss fake [0.70293826, 0.5234375]
# --------------------------------
#  d_ loss  [0.63938534 0.59765625]
# 9572 [D loss: 0.639385, acc.: 59.77%] [G loss: 0.840385]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6112968, 0.6953125]
# --------------------------------
# d loss fake [0.61910164, 0.6796875]
# --------------------------------
#  d_ loss  [0.6151992 0.6875   ]
# 9573 [D loss: 0.615199, acc.: 68.75%] [G loss: 0.879271]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.56885463, 0.7109375]
# --------------------------------
# d loss fake [0.6185266, 0.6484375]
# --------------------------------
#  d_ loss  [0.59369063 0.6796875 ]
# 9574 [D loss: 0.593691, acc.: 67.97%] [G loss: 0.889395]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.61517406, 0.6640625]
# --------------------------------
# d loss fake [0.6442445, 0.609375]
# --------------------------------
#  d_ loss  [0.62970924 0.63671875]
# 9575 [D loss: 0.629709, acc.: 63.67%] [G loss: 0.887323]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.65043676, 0.671875]
# --------------------------------
# d loss fake [0.6439593, 0.65625]
# --------------------------------
#  d_ loss  [0.647198  0.6640625]
# 9576 [D loss: 0.647198, acc.: 66.41%] [G loss: 0.852607]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62606096, 0.65625]
# --------------------------------
# d loss fake [0.60690224, 0.703125]
# --------------------------------
#  d_ loss  [0.6164816 0.6796875]
# 9577 [D loss: 0.616482, acc.: 67.97%] [G loss: 0.839310]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62855256, 0.6171875]
# --------------------------------
# d loss fake [0.68720436, 0.6015625]
# --------------------------------
#  d_ loss  [0.65787846 0.609375  ]
# 9578 [D loss: 0.657878, acc.: 60.94%] [G loss: 0.852500]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6762836, 0.5625]
# --------------------------------
# d loss fake [0.6703348, 0.6015625]
# --------------------------------
#  d_ loss  [0.6733092  0.58203125]
# 9579 [D loss: 0.673309, acc.: 58.20%] [G loss: 0.884722]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6202555, 0.625]
# --------------------------------
# d loss fake [0.63117206, 0.6484375]
# --------------------------------
#  d_ loss  [0.62571377 0.63671875]
# 9580 [D loss: 0.625714, acc.: 63.67%] [G loss: 0.917904]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6874248, 0.59375]
# --------------------------------
# d loss fake [0.6178252, 0.6796875]
# --------------------------------
#  d_ loss  [0.65262496 0.63671875]
# 9581 [D loss: 0.652625, acc.: 63.67%] [G loss: 0.915486]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.620241, 0.6484375]
# --------------------------------
# d loss fake [0.612384, 0.6953125]
# --------------------------------
#  d_ loss  [0.6163125 0.671875 ]
# 9582 [D loss: 0.616313, acc.: 67.19%] [G loss: 0.891703]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63497967, 0.625]
# --------------------------------
# d loss fake [0.6671073, 0.5703125]
# --------------------------------
#  d_ loss  [0.6510435  0.59765625]
# 9583 [D loss: 0.651043, acc.: 59.77%] [G loss: 0.876130]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6318287, 0.6953125]
# --------------------------------
# d loss fake [0.5922792, 0.7734375]
# --------------------------------
#  d_ loss  [0.612054 0.734375]
# 9584 [D loss: 0.612054, acc.: 73.44%] [G loss: 0.852247]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6069507, 0.6875]
# --------------------------------
# d loss fake [0.60832036, 0.65625]
# --------------------------------
#  d_ loss  [0.6076355 0.671875 ]
# 9585 [D loss: 0.607635, acc.: 67.19%] [G loss: 0.829570]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6453091, 0.5703125]
# --------------------------------
# d loss fake [0.59794664, 0.6796875]
# --------------------------------
#  d_ loss  [0.62162787 0.625     ]
# 9586 [D loss: 0.621628, acc.: 62.50%] [G loss: 0.872941]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.627807, 0.625]
# --------------------------------
# d loss fake [0.6614891, 0.6015625]
# --------------------------------
#  d_ loss  [0.6446481  0.61328125]
# 9587 [D loss: 0.644648, acc.: 61.33%] [G loss: 0.855160]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62155175, 0.6875]
# --------------------------------
# d loss fake [0.6768292, 0.6015625]
# --------------------------------
#  d_ loss  [0.6491905  0.64453125]
# 9588 [D loss: 0.649190, acc.: 64.45%] [G loss: 0.867672]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.633, 0.65625]
# --------------------------------
# d loss fake [0.6356417, 0.65625]
# --------------------------------
#  d_ loss  [0.63432086 0.65625   ]
# 9589 [D loss: 0.634321, acc.: 65.62%] [G loss: 0.842733]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62617093, 0.6796875]
# --------------------------------
# d loss fake [0.62710506, 0.6796875]
# --------------------------------
#  d_ loss  [0.626638  0.6796875]
# 9590 [D loss: 0.626638, acc.: 67.97%] [G loss: 0.810099]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.59867597, 0.71875]
# --------------------------------
# d loss fake [0.64813256, 0.625]
# --------------------------------
#  d_ loss  [0.62340426 0.671875  ]
# 9591 [D loss: 0.623404, acc.: 67.19%] [G loss: 0.871853]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62439644, 0.625]
# --------------------------------
# d loss fake [0.5813788, 0.6953125]
# --------------------------------
#  d_ loss  [0.60288763 0.66015625]
# 9592 [D loss: 0.602888, acc.: 66.02%] [G loss: 0.794394]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.56981254, 0.703125]
# --------------------------------
# d loss fake [0.61147094, 0.7109375]
# --------------------------------
#  d_ loss  [0.59064174 0.70703125]
# 9593 [D loss: 0.590642, acc.: 70.70%] [G loss: 0.823162]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5960717, 0.703125]
# --------------------------------
# d loss fake [0.67510706, 0.578125]
# --------------------------------
#  d_ loss  [0.63558936 0.640625  ]
# 9594 [D loss: 0.635589, acc.: 64.06%] [G loss: 0.838674]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6371396, 0.65625]
# --------------------------------
# d loss fake [0.6607577, 0.6015625]
# --------------------------------
#  d_ loss  [0.64894867 0.62890625]
# 9595 [D loss: 0.648949, acc.: 62.89%] [G loss: 0.836929]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6671628, 0.59375]
# --------------------------------
# d loss fake [0.64183676, 0.625]
# --------------------------------
#  d_ loss  [0.65449977 0.609375  ]
# 9596 [D loss: 0.654500, acc.: 60.94%] [G loss: 0.823458]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.64984494, 0.6328125]
# --------------------------------
# d loss fake [0.7043104, 0.5625]
# --------------------------------
#  d_ loss  [0.67707765 0.59765625]
# 9597 [D loss: 0.677078, acc.: 59.77%] [G loss: 0.857240]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6600605, 0.6171875]
# --------------------------------
# d loss fake [0.613809, 0.6796875]
# --------------------------------
#  d_ loss  [0.63693476 0.6484375 ]
# 9598 [D loss: 0.636935, acc.: 64.84%] [G loss: 0.842001]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6580112, 0.6171875]
# --------------------------------
# d loss fake [0.68886757, 0.546875]
# --------------------------------
#  d_ loss  [0.6734394  0.58203125]
# 9599 [D loss: 0.673439, acc.: 58.20%] [G loss: 0.831257]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6486776, 0.6015625]
# --------------------------------
# d loss fake [0.6589795, 0.609375]
# --------------------------------
#  d_ loss  [0.6538285  0.60546875]
# 9600 [D loss: 0.653829, acc.: 60.55%] [G loss: 0.819961]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6678577, 0.5234375]
# --------------------------------
# d loss fake [0.64103377, 0.625]
# --------------------------------
#  d_ loss  [0.65444577 0.57421875]
# 9601 [D loss: 0.654446, acc.: 57.42%] [G loss: 0.807689]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.65186334, 0.609375]
# --------------------------------
# d loss fake [0.64185596, 0.6171875]
# --------------------------------
#  d_ loss  [0.64685965 0.61328125]
# 9602 [D loss: 0.646860, acc.: 61.33%] [G loss: 0.786479]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.58396804, 0.75]
# --------------------------------
# d loss fake [0.65131056, 0.625]
# --------------------------------
#  d_ loss  [0.6176393 0.6875   ]
# 9603 [D loss: 0.617639, acc.: 68.75%] [G loss: 0.807960]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.61919737, 0.625]
# --------------------------------
# d loss fake [0.6549812, 0.5859375]
# --------------------------------
#  d_ loss  [0.63708925 0.60546875]
# 9604 [D loss: 0.637089, acc.: 60.55%] [G loss: 0.834905]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.66956264, 0.6015625]
# --------------------------------
# d loss fake [0.6541889, 0.609375]
# --------------------------------
#  d_ loss  [0.6618757  0.60546875]
# 9605 [D loss: 0.661876, acc.: 60.55%] [G loss: 0.860285]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.636284, 0.640625]
# --------------------------------
# d loss fake [0.6188259, 0.671875]
# --------------------------------
#  d_ loss  [0.62755495 0.65625   ]
# 9606 [D loss: 0.627555, acc.: 65.62%] [G loss: 0.867353]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5871543, 0.6796875]
# --------------------------------
# d loss fake [0.6226326, 0.640625]
# --------------------------------
#  d_ loss  [0.60489345 0.66015625]
# 9607 [D loss: 0.604893, acc.: 66.02%] [G loss: 0.845847]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60854053, 0.6640625]
# --------------------------------
# d loss fake [0.7047839, 0.5234375]
# --------------------------------
#  d_ loss  [0.6566622 0.59375  ]
# 9608 [D loss: 0.656662, acc.: 59.38%] [G loss: 0.918407]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6216265, 0.625]
# --------------------------------
# d loss fake [0.6294565, 0.6484375]
# --------------------------------
#  d_ loss  [0.6255415  0.63671875]
# 9609 [D loss: 0.625542, acc.: 63.67%] [G loss: 0.884844]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62270945, 0.640625]
# --------------------------------
# d loss fake [0.63940305, 0.625]
# --------------------------------
#  d_ loss  [0.63105625 0.6328125 ]
# 9610 [D loss: 0.631056, acc.: 63.28%] [G loss: 0.875006]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6656076, 0.5625]
# --------------------------------
# d loss fake [0.6702299, 0.6171875]
# --------------------------------
#  d_ loss  [0.66791874 0.58984375]
# 9611 [D loss: 0.667919, acc.: 58.98%] [G loss: 0.852397]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6157154, 0.6640625]
# --------------------------------
# d loss fake [0.63952446, 0.609375]
# --------------------------------
#  d_ loss  [0.6276199  0.63671875]
# 9612 [D loss: 0.627620, acc.: 63.67%] [G loss: 0.849067]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.60992646, 0.7265625]
# --------------------------------
# d loss fake [0.6856569, 0.578125]
# --------------------------------
#  d_ loss  [0.6477917  0.65234375]
# 9613 [D loss: 0.647792, acc.: 65.23%] [G loss: 0.836914]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6200485, 0.65625]
# --------------------------------
# d loss fake [0.658795, 0.6328125]
# --------------------------------
#  d_ loss  [0.63942176 0.64453125]
# 9614 [D loss: 0.639422, acc.: 64.45%] [G loss: 0.876274]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6574383, 0.59375]
# --------------------------------
# d loss fake [0.61487126, 0.671875]
# --------------------------------
#  d_ loss  [0.6361548 0.6328125]
# 9615 [D loss: 0.636155, acc.: 63.28%] [G loss: 0.871194]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6163856, 0.6875]
# --------------------------------
# d loss fake [0.66319317, 0.625]
# --------------------------------
#  d_ loss  [0.63978934 0.65625   ]
# 9616 [D loss: 0.639789, acc.: 65.62%] [G loss: 0.834581]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6308131, 0.6953125]
# --------------------------------
# d loss fake [0.6174415, 0.65625]
# --------------------------------
#  d_ loss  [0.62412727 0.67578125]
# 9617 [D loss: 0.624127, acc.: 67.58%] [G loss: 0.812441]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# ...
# --------------------------------
# d loss fake [0.5938705, 0.7109375]
# --------------------------------
#  d_ loss  [0.6065113 0.6953125]
# 9954 [D loss: 0.606511, acc.: 69.53%] [G loss: 0.859358]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5941331, 0.6953125]
# --------------------------------
# d loss fake [0.6777125, 0.5625]
# --------------------------------
#  d_ loss  [0.6359228  0.62890625]
# 9955 [D loss: 0.635923, acc.: 62.89%] [G loss: 0.851074]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6388202, 0.6796875]
# --------------------------------
# d loss fake [0.7249445, 0.5703125]
# --------------------------------
#  d_ loss  [0.6818823 0.625    ]
# 9956 [D loss: 0.681882, acc.: 62.50%] [G loss: 0.827486]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6127734, 0.671875]
# --------------------------------
# d loss fake [0.6297222, 0.671875]
# --------------------------------
#  d_ loss  [0.62124777 0.671875  ]
# 9957 [D loss: 0.621248, acc.: 67.19%] [G loss: 0.841996]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62599933, 0.6484375]
# --------------------------------
# d loss fake [0.6696365, 0.6328125]
# --------------------------------
#  d_ loss  [0.6478179 0.640625 ]
# 9958 [D loss: 0.647818, acc.: 64.06%] [G loss: 0.844845]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6188177, 0.6484375]
# --------------------------------
# d loss fake [0.6513548, 0.625]
# --------------------------------
#  d_ loss  [0.63508624 0.63671875]
# 9959 [D loss: 0.635086, acc.: 63.67%] [G loss: 0.879198]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62343395, 0.6640625]
# --------------------------------
# d loss fake [0.670284, 0.5546875]
# --------------------------------
#  d_ loss  [0.64685893 0.609375  ]
# 9960 [D loss: 0.646859, acc.: 60.94%] [G loss: 0.860540]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6224425, 0.671875]
# --------------------------------
# d loss fake [0.65947556, 0.546875]
# --------------------------------
#  d_ loss  [0.640959 0.609375]
# 9961 [D loss: 0.640959, acc.: 60.94%] [G loss: 0.853824]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6112524, 0.7109375]
# --------------------------------
# d loss fake [0.6378497, 0.625]
# --------------------------------
#  d_ loss  [0.62455106 0.66796875]
# 9962 [D loss: 0.624551, acc.: 66.80%] [G loss: 0.870085]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6333769, 0.640625]
# --------------------------------
# d loss fake [0.6634268, 0.6484375]
# --------------------------------
#  d_ loss  [0.64840186 0.64453125]
# 9963 [D loss: 0.648402, acc.: 64.45%] [G loss: 0.876440]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6354069, 0.640625]
# --------------------------------
# d loss fake [0.6829373, 0.546875]
# --------------------------------
#  d_ loss  [0.6591721 0.59375  ]
# 9964 [D loss: 0.659172, acc.: 59.38%] [G loss: 0.858516]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6579313, 0.609375]
# --------------------------------
# d loss fake [0.646183, 0.65625]
# --------------------------------
#  d_ loss  [0.6520572 0.6328125]
# 9965 [D loss: 0.652057, acc.: 63.28%] [G loss: 0.892030]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.61620396, 0.6796875]
# --------------------------------
# d loss fake [0.61318684, 0.65625]
# --------------------------------
#  d_ loss  [0.6146954  0.66796875]
# 9966 [D loss: 0.614695, acc.: 66.80%] [G loss: 0.904983]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.65523666, 0.5859375]
# --------------------------------
# d loss fake [0.64715517, 0.6328125]
# --------------------------------
#  d_ loss  [0.6511959 0.609375 ]
# 9967 [D loss: 0.651196, acc.: 60.94%] [G loss: 0.861586]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6263941, 0.640625]
# --------------------------------
# d loss fake [0.6094574, 0.6953125]
# --------------------------------
#  d_ loss  [0.61792576 0.66796875]
# 9968 [D loss: 0.617926, acc.: 66.80%] [G loss: 0.820484]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6711886, 0.578125]
# --------------------------------
# d loss fake [0.6857325, 0.5625]
# --------------------------------
#  d_ loss  [0.67846054 0.5703125 ]
# 9969 [D loss: 0.678461, acc.: 57.03%] [G loss: 0.805083]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5820843, 0.6953125]
# --------------------------------
# d loss fake [0.6701494, 0.5859375]
# --------------------------------
#  d_ loss  [0.6261169 0.640625 ]
# 9970 [D loss: 0.626117, acc.: 64.06%] [G loss: 0.812030]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6331851, 0.625]
# --------------------------------
# d loss fake [0.68582845, 0.5390625]
# --------------------------------
#  d_ loss  [0.6595068  0.58203125]
# 9971 [D loss: 0.659507, acc.: 58.20%] [G loss: 0.878605]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62590706, 0.625]
# --------------------------------
# d loss fake [0.6290201, 0.65625]
# --------------------------------
#  d_ loss  [0.6274636 0.640625 ]
# 9972 [D loss: 0.627464, acc.: 64.06%] [G loss: 0.834441]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6121421, 0.6953125]
# --------------------------------
# d loss fake [0.66014403, 0.6171875]
# --------------------------------
#  d_ loss  [0.6361431 0.65625  ]
# 9973 [D loss: 0.636143, acc.: 65.62%] [G loss: 0.856035]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6170511, 0.6171875]
# --------------------------------
# d loss fake [0.63922817, 0.640625]
# --------------------------------
#  d_ loss  [0.6281396  0.62890625]
# 9974 [D loss: 0.628140, acc.: 62.89%] [G loss: 0.842494]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6500396, 0.5859375]
# --------------------------------
# d loss fake [0.6192517, 0.703125]
# --------------------------------
#  d_ loss  [0.6346457  0.64453125]
# 9975 [D loss: 0.634646, acc.: 64.45%] [G loss: 0.859145]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.62173104, 0.65625]
# --------------------------------
# d loss fake [0.6317673, 0.6328125]
# --------------------------------
#  d_ loss  [0.62674916 0.64453125]
# 9976 [D loss: 0.626749, acc.: 64.45%] [G loss: 0.830425]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.640665, 0.609375]
# --------------------------------
# d loss fake [0.6425983, 0.640625]
# --------------------------------
#  d_ loss  [0.6416316 0.625    ]
# 9977 [D loss: 0.641632, acc.: 62.50%] [G loss: 0.872118]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.61416495, 0.6953125]
# --------------------------------
# d loss fake [0.6214077, 0.6953125]
# --------------------------------
#  d_ loss  [0.6177863 0.6953125]
# 9978 [D loss: 0.617786, acc.: 69.53%] [G loss: 0.864478]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.64065146, 0.65625]
# --------------------------------
# d loss fake [0.6619594, 0.59375]
# --------------------------------
#  d_ loss  [0.65130544 0.625     ]
# 9979 [D loss: 0.651305, acc.: 62.50%] [G loss: 0.870148]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6129014, 0.65625]
# --------------------------------
# d loss fake [0.61598766, 0.6953125]
# --------------------------------
#  d_ loss  [0.6144445  0.67578125]
# 9980 [D loss: 0.614444, acc.: 67.58%] [G loss: 0.845517]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6686397, 0.5390625]
# --------------------------------
# d loss fake [0.6346147, 0.65625]
# --------------------------------
#  d_ loss  [0.6516272  0.59765625]
# 9981 [D loss: 0.651627, acc.: 59.77%] [G loss: 0.861613]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.61829114, 0.671875]
# --------------------------------
# d loss fake [0.6557713, 0.59375]
# --------------------------------
#  d_ loss  [0.6370312 0.6328125]
# 9982 [D loss: 0.637031, acc.: 63.28%] [G loss: 0.876433]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5862407, 0.7421875]
# --------------------------------
# d loss fake [0.6533611, 0.65625]
# --------------------------------
#  d_ loss  [0.6198009  0.69921875]
# 9983 [D loss: 0.619801, acc.: 69.92%] [G loss: 0.779472]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.643592, 0.6171875]
# --------------------------------
# d loss fake [0.6609764, 0.5859375]
# --------------------------------
#  d_ loss  [0.6522842 0.6015625]
# 9984 [D loss: 0.652284, acc.: 60.16%] [G loss: 0.848485]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5841266, 0.75]
# --------------------------------
# d loss fake [0.65923375, 0.5703125]
# --------------------------------
#  d_ loss  [0.62168014 0.66015625]
# 9985 [D loss: 0.621680, acc.: 66.02%] [G loss: 0.869923]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63142824, 0.609375]
# --------------------------------
# d loss fake [0.6669871, 0.5390625]
# --------------------------------
#  d_ loss  [0.6492077  0.57421875]
# 9986 [D loss: 0.649208, acc.: 57.42%] [G loss: 0.910613]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6333865, 0.6015625]
# --------------------------------
# d loss fake [0.6141099, 0.6484375]
# --------------------------------
#  d_ loss  [0.6237482 0.625    ]
# 9987 [D loss: 0.623748, acc.: 62.50%] [G loss: 0.822678]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6297325, 0.6875]
# --------------------------------
# d loss fake [0.67191064, 0.578125]
# --------------------------------
#  d_ loss  [0.65082157 0.6328125 ]
# 9988 [D loss: 0.650822, acc.: 63.28%] [G loss: 0.808407]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6324501, 0.6640625]
# --------------------------------
# d loss fake [0.6425108, 0.625]
# --------------------------------
#  d_ loss  [0.63748044 0.64453125]
# 9989 [D loss: 0.637480, acc.: 64.45%] [G loss: 0.830694]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5783313, 0.703125]
# --------------------------------
# d loss fake [0.66710955, 0.5703125]
# --------------------------------
#  d_ loss  [0.6227204  0.63671875]
# 9990 [D loss: 0.622720, acc.: 63.67%] [G loss: 0.841955]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6128846, 0.6640625]
# --------------------------------
# d loss fake [0.6022779, 0.71875]
# --------------------------------
#  d_ loss  [0.60758126 0.69140625]
# 9991 [D loss: 0.607581, acc.: 69.14%] [G loss: 0.850738]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.63313776, 0.6328125]
# --------------------------------
# d loss fake [0.62415147, 0.65625]
# --------------------------------
#  d_ loss  [0.6286446  0.64453125]
# 9992 [D loss: 0.628645, acc.: 64.45%] [G loss: 0.830676]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6120306, 0.6484375]
# --------------------------------
# d loss fake [0.675184, 0.5625]
# --------------------------------
#  d_ loss  [0.6436073  0.60546875]
# 9993 [D loss: 0.643607, acc.: 60.55%] [G loss: 0.821422]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.58499646, 0.765625]
# --------------------------------
# d loss fake [0.6157551, 0.703125]
# --------------------------------
#  d_ loss  [0.6003758 0.734375 ]
# 9994 [D loss: 0.600376, acc.: 73.44%] [G loss: 0.840407]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.5993985, 0.6953125]
# --------------------------------
# d loss fake [0.6102961, 0.703125]
# --------------------------------
#  d_ loss  [0.6048473  0.69921875]
# 9995 [D loss: 0.604847, acc.: 69.92%] [G loss: 0.853302]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.593595, 0.6640625]
# --------------------------------
# d loss fake [0.61506474, 0.6796875]
# --------------------------------
#  d_ loss  [0.6043299 0.671875 ]
# 9996 [D loss: 0.604330, acc.: 67.19%] [G loss: 0.850037]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6009852, 0.6953125]
# --------------------------------
# d loss fake [0.65542305, 0.6015625]
# --------------------------------
#  d_ loss  [0.6282041 0.6484375]
# 9997 [D loss: 0.628204, acc.: 64.84%] [G loss: 0.833979]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6478673, 0.6015625]
# --------------------------------
# d loss fake [0.6557281, 0.59375]
# --------------------------------
#  d_ loss  [0.6517977  0.59765625]
# 9998 [D loss: 0.651798, acc.: 59.77%] [G loss: 0.802001]
# --------------------------------
# this is idx.shape:  (128,)
# --------------------------------
# --------------------------------
# d loss real [0.6208018, 0.6953125]
# --------------------------------
# d loss fake [0.6381577, 0.6015625]
# --------------------------------
#  d_ loss  [0.62947977 0.6484375 ]
# 9999 [D loss: 0.629480, acc.: 64.84%] [G loss: 0.835113]

# %% [markdown]
# 10000 epochs

# %% [markdown]
# Newnoise with sigma = 0.8

# %%
import matplotlib.pyplot as plt

noise = np.random.normal(0, 1, (36,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 6
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# 1000 epochs:

# %% [markdown]
# Newnoise with sigma = 0.8

# %%
import matplotlib.pyplot as plt

noise = np.random.normal(0, 1, (36,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 6
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# newnoise_with sigma = 0.5

# %%
import matplotlib.pyplot as plt

noise = np.random.normal(0, 1, (36,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 6
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# New noise with plus

# %%
import matplotlib.pyplot as plt

noise = np.random.normal(0, 1, (36,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 6
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# New noise with mines

# %%
import matplotlib.pyplot as plt

noise = np.random.normal(0, 1, (36,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 6
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# Model with new noise (with multiply):

# %%
noise = np.random.normal(0, 1, (20,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape
# Out:
# (20, 28, 28, 1)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))
columns = 5
rows = 4
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# Baseline:

# %%
noise = np.random.normal(0, 1, (48,128))
gen_imgs = gan.generator.predict(noise)
gen_imgs.shape

fig = plt.figure(figsize=(8, 8))
columns = 6
rows = 8
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# Model with while:

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))
columns = 5
rows = 4
for i in range(1, columns*rows +1):
  fig.add_subplot(rows, columns, i)
  a = np.reshape(gen_imgs[i-1], (28,28))
  plt.imshow(a)
plt.show()

# %% [markdown]
# # Extra

# %%
noise = np.random.normal(0, 1, (64, 100))
gen_imgs = gan.generator.predict(noise)
g_loss_discrimination = -np.linalg.norm(gen_imgs)
g_loss_discrimination
# Out:
# -43.594784
