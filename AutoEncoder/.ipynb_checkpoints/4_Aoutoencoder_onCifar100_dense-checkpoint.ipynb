# %%
from keras.layers import Input, Dense
from keras.models import Model

from keras.datasets import mnist, cifar100
import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
(x_train, _), (x_test, _) = cifar100.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 3072)
# (10000, 3072)

# %% [markdown]
# # Model

# %%
# size of encoded representations
encoding_dim = 64

# this is our input placeholder
input_img = Input(shape=(3072,))

# encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)

# map input to its encoded representation
encoder = Model(input_img, encoded)


# input to the decoder
encoded_input = Input(shape=(encoding_dim,))

# reconstruction of the input
decoded = Dense(3072, activation='relu')(encoded_input)
decoded = Dense(3072, activation='sigmoid')(decoded)

# decoder model
decoder = Model(encoded_input, decoded)

# map an input to its reconstruction
out = decoder(encoder(input_img))

autoencoder = Model(input_img,out)

# %%
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# model_1 (Model)              (None, 64)                196672
# _________________________________________________________________
# model_2 (Model)              (None, 3072)              9639936
# =================================================================
# Total params: 9,836,608
# Trainable params: 9,836,608
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.6034 - accuracy: 0.0237 - val_loss: 0.5755 - val_accuracy: 0.0242
# Epoch 2/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5718 - accuracy: 0.0245 - val_loss: 0.5689 - val_accuracy: 0.0243
# Epoch 3/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5680 - accuracy: 0.0245 - val_loss: 0.5667 - val_accuracy: 0.0243
# Epoch 4/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5668 - accuracy: 0.0245 - val_loss: 0.5655 - val_accuracy: 0.0243
# Epoch 5/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5656 - accuracy: 0.0245 - val_loss: 0.5649 - val_accuracy: 0.0243
# Epoch 6/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5648 - accuracy: 0.0245 - val_loss: 0.5636 - val_accuracy: 0.0243
# Epoch 7/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5641 - accuracy: 0.0245 - val_loss: 0.5637 - val_accuracy: 0.0243
# Epoch 8/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5635 - accuracy: 0.0245 - val_loss: 0.5629 - val_accuracy: 0.0243
# Epoch 9/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5632 - accuracy: 0.0245 - val_loss: 0.5629 - val_accuracy: 0.0243
# Epoch 10/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5628 - accuracy: 0.0245 - val_loss: 0.5632 - val_accuracy: 0.0243
# Epoch 11/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5626 - accuracy: 0.0245 - val_loss: 0.5624 - val_accuracy: 0.0243
# Epoch 12/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5623 - accuracy: 0.0245 - val_loss: 0.5630 - val_accuracy: 0.0243
# Epoch 13/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5621 - accuracy: 0.0245 - val_loss: 0.5620 - val_accuracy: 0.0243
# Epoch 14/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5618 - accuracy: 0.0245 - val_loss: 0.5621 - val_accuracy: 0.0243
# Epoch 15/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5617 - accuracy: 0.0245 - val_loss: 0.5625 - val_accuracy: 0.0243
# Epoch 16/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5615 - accuracy: 0.0245 - val_loss: 0.5617 - val_accuracy: 0.0243
# Epoch 17/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5614 - accuracy: 0.0245 - val_loss: 0.5618 - val_accuracy: 0.0243
# Epoch 18/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5611 - accuracy: 0.0246 - val_loss: 0.5611 - val_accuracy: 0.0243
# Epoch 19/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5607 - accuracy: 0.0246 - val_loss: 0.5614 - val_accuracy: 0.0243
# Epoch 20/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5606 - accuracy: 0.0246 - val_loss: 0.5610 - val_accuracy: 0.0243
# Epoch 21/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5604 - accuracy: 0.0246 - val_loss: 0.5607 - val_accuracy: 0.0243
# Epoch 22/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5602 - accuracy: 0.0246 - val_loss: 0.5609 - val_accuracy: 0.0243
# Epoch 23/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5601 - accuracy: 0.0246 - val_loss: 0.5610 - val_accuracy: 0.0243
# Epoch 24/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5599 - accuracy: 0.0246 - val_loss: 0.5609 - val_accuracy: 0.0243
# Epoch 25/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5600 - accuracy: 0.0246 - val_loss: 0.5604 - val_accuracy: 0.0243
# Epoch 26/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.5599 - accuracy: 0.0246 - val_loss: 0.5604 - val_accuracy: 0.0243
# Epoch 27/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.5596 - accuracy: 0.0246 - val_loss: 0.5604 - val_accuracy: 0.0243
# Epoch 28/50
# 50000/50000 [==============================] - 4s 90us/step - loss: 0.5597 - accuracy: 0.0246 - val_loss: 0.5603 - val_accuracy: 0.0243
# Epoch 29/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5596 - accuracy: 0.0246 - val_loss: 0.5604 - val_accuracy: 0.0243
# Epoch 30/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5594 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 31/50
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.5593 - accuracy: 0.0246 - val_loss: 0.5608 - val_accuracy: 0.0243
# Epoch 32/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5593 - accuracy: 0.0246 - val_loss: 0.5605 - val_accuracy: 0.0243
# Epoch 33/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5594 - accuracy: 0.0246 - val_loss: 0.5603 - val_accuracy: 0.0243
# Epoch 34/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5592 - accuracy: 0.0246 - val_loss: 0.5607 - val_accuracy: 0.0243
# Epoch 35/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5591 - accuracy: 0.0246 - val_loss: 0.5604 - val_accuracy: 0.0243
# Epoch 36/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5590 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 37/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5590 - accuracy: 0.0246 - val_loss: 0.5606 - val_accuracy: 0.0243
# Epoch 38/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5589 - accuracy: 0.0246 - val_loss: 0.5613 - val_accuracy: 0.0243
# Epoch 39/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5588 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 40/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5588 - accuracy: 0.0246 - val_loss: 0.5603 - val_accuracy: 0.0243
# Epoch 41/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5588 - accuracy: 0.0246 - val_loss: 0.5616 - val_accuracy: 0.0243
# Epoch 42/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5587 - accuracy: 0.0246 - val_loss: 0.5601 - val_accuracy: 0.0243
# Epoch 43/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5586 - accuracy: 0.0246 - val_loss: 0.5603 - val_accuracy: 0.0243
# Epoch 44/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5586 - accuracy: 0.0246 - val_loss: 0.5600 - val_accuracy: 0.0243
# Epoch 45/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5586 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 46/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5584 - accuracy: 0.0246 - val_loss: 0.5603 - val_accuracy: 0.0243
# Epoch 47/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5584 - accuracy: 0.0246 - val_loss: 0.5605 - val_accuracy: 0.0243
# Epoch 48/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5584 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 49/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5583 - accuracy: 0.0246 - val_loss: 0.5602 - val_accuracy: 0.0243
# Epoch 50/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5583 - accuracy: 0.0246 - val_loss: 0.5601 - val_accuracy: 0.0243

# %%
scores = autoencoder.evaluate(x_test, x_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 2.43%

# %% [markdown]
# # Visualize

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(32, 96))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(32, 96))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(64, 48))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(64, 48))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
