# %%
from keras.layers import Input, Dense
from keras.models import Model

from keras.datasets import mnist, cifar100
import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
(x_train, _), (x_test, _) = cifar100.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 3072)
# (10000, 3072)

# %% [markdown]
# # Model

# %%
# size of encoded representations
encoding_dim = 64

# input placeholder
input_img = Input(shape=(3072,))


# encoded representation of the input
encoded = Dense(2300, activation='relu')(input_img)
encoded = Dense(1500, activation='relu')(encoded)
encoded = Dense(522, activation='relu')(encoded)
encoded = Dense(256, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# map input to its encoded representation
encoder = Model(input_img, encoded)


# input to the decoder
encoded_input = Input(shape=(encoding_dim,))

# reconstruction of the input
decoded = Dense(256, activation='sigmoid')(encoded_input)
decoded = Dense(522, activation='sigmoid')(decoded)
decoded = Dense(1500, activation='sigmoid')(decoded)
decoded = Dense(2300, activation='sigmoid')(decoded)
decoded = Dense(3072, activation='sigmoid')(decoded)

# decoder model
decoder = Model(encoded_input, decoded)

# map an input to its reconstruction
out = decoder(encoder(input_img))
autoencoder = Model(input_img,out)

# %%
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# model_1 (Model)              (None, 64)                11453258
# _________________________________________________________________
# model_2 (Model)              (None, 3072)              11456266
# ...
# Total params: 22,909,524
# Trainable params: 22,909,524
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 10s 193us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 2/50
# 50000/50000 [==============================] - 9s 188us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 3/50
# 50000/50000 [==============================] - 9s 189us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 4/50
# 50000/50000 [==============================] - 9s 188us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 5/50
# 50000/50000 [==============================] - 9s 188us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 6/50
# 50000/50000 [==============================] - 9s 189us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 7/50
# 50000/50000 [==============================] - 9s 190us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 8/50
# 50000/50000 [==============================] - 9s 189us/step - loss: 0.6883 - val_loss: 0.6883
# Epoch 9/50
# ...

# %% [markdown]
# # Visualize

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(64, 48))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(64, 48))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
