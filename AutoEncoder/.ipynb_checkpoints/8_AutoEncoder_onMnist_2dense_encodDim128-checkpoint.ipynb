# %%
from keras.layers import Input, Dense
from keras.models import Model

from keras.datasets import mnist, cifar100
import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# # Model

# %%
# size of encoded representations
encoding_dim = 128

# input placeholder
input_img = Input(shape=(784,))


# encoded representation of the input
encoded = Dense(600, activation='relu')(input_img)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# map input to its encoded representation
encoder = Model(input_img, encoded)


# input to the decoder
encoded_input = Input(shape=(encoding_dim,))

# reconstruction of the input
decoded = Dense(128, activation='sigmoid')(encoded_input)
decoded = Dense(784, activation='sigmoid')(decoded)

# decoder model
decoder = Model(encoded_input, decoded)

# map an input to its reconstruction
out = decoder(encoder(input_img))
autoencoder = Model(input_img,out)

# %%
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 128)               547928
# _________________________________________________________________
# model_2 (Model)              (None, 784)               117648
# =================================================================
# Total params: 665,576
# Trainable params: 665,576
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.3552 - val_loss: 0.2743
# Epoch 2/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2702 - val_loss: 0.2675
# Epoch 3/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2666 - val_loss: 0.2655
# Epoch 4/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2653 - val_loss: 0.2647
# Epoch 5/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2646 - val_loss: 0.2642
# Epoch 6/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2642 - val_loss: 0.2638
# Epoch 7/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2640 - val_loss: 0.2636
# Epoch 8/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2638 - val_loss: 0.2634
# Epoch 9/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2636 - val_loss: 0.2633
# Epoch 10/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2635 - val_loss: 0.2632
# Epoch 11/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2634 - val_loss: 0.2631
# Epoch 12/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2633 - val_loss: 0.2630
# Epoch 13/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2632 - val_loss: 0.2629
# Epoch 14/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2631 - val_loss: 0.2627
# Epoch 15/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2630 - val_loss: 0.2626
# Epoch 16/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2628 - val_loss: 0.2624
# Epoch 17/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2625 - val_loss: 0.2621
# Epoch 18/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2622 - val_loss: 0.2618
# Epoch 19/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2619 - val_loss: 0.2614
# Epoch 20/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2615 - val_loss: 0.2610
# Epoch 21/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2611 - val_loss: 0.2605
# Epoch 22/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2607 - val_loss: 0.2601
# Epoch 23/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2602 - val_loss: 0.2597
# Epoch 24/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2598 - val_loss: 0.2592
# Epoch 25/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2593 - val_loss: 0.2587
# Epoch 26/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2588 - val_loss: 0.2582
# Epoch 27/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2584 - val_loss: 0.2577
# Epoch 28/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2579 - val_loss: 0.2572
# Epoch 29/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2573 - val_loss: 0.2567
# Epoch 30/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2567 - val_loss: 0.2561
# Epoch 31/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2561 - val_loss: 0.2554
# Epoch 32/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2555 - val_loss: 0.2547
# Epoch 33/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2548 - val_loss: 0.2539
# Epoch 34/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2540 - val_loss: 0.2531
# Epoch 35/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2532 - val_loss: 0.2523
# Epoch 36/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2524 - val_loss: 0.2514
# Epoch 37/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2515 - val_loss: 0.2506
# Epoch 38/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2506 - val_loss: 0.2497
# Epoch 39/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2498 - val_loss: 0.2489
# Epoch 40/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2490 - val_loss: 0.2481
# Epoch 41/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2482 - val_loss: 0.2473
# Epoch 42/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2474 - val_loss: 0.2465
# Epoch 43/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2467 - val_loss: 0.2458
# Epoch 44/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2459 - val_loss: 0.2450
# Epoch 45/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2452 - val_loss: 0.2443
# Epoch 46/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2445 - val_loss: 0.2436
# Epoch 47/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2438 - val_loss: 0.2429
# Epoch 48/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2431 - val_loss: 0.2422
# Epoch 49/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2423 - val_loss: 0.2414
# Epoch 50/50
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.2416 - val_loss: 0.2407

# %% [markdown]
# # Visualize

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
