# %%
from keras.layers import Input, Dense
from keras.models import Model

from keras.datasets import mnist, cifar100
import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# # Model

# %%
# size of encoded representations
encoding_dim = 64

# input placeholder
input_img = Input(shape=(784,))


# encoded representation of the input
encoded = Dense(600, activation='relu')(input_img)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# map input to its encoded representation
encoder = Model(input_img, encoded)


# input to the decoder
encoded_input = Input(shape=(encoding_dim,))

# reconstruction of the input
decoded = Dense(128, activation='sigmoid')(encoded_input)
decoded = Dense(256, activation='sigmoid')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# decoder model
decoder = Model(encoded_input, decoded)

# map an input to its reconstruction
out = decoder(encoder(input_img))
autoencoder = Model(input_img,out)

# %%
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 64)                556184
# _________________________________________________________________
# model_2 (Model)              (None, 784)               242832
# =================================================================
# Total params: 799,016
# Trainable params: 799,016
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.3340 - val_loss: 0.2712
# Epoch 2/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2678 - val_loss: 0.2655
# Epoch 3/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2650 - val_loss: 0.2641
# Epoch 4/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2641 - val_loss: 0.2635
# Epoch 5/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2636 - val_loss: 0.2631
# Epoch 6/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2631 - val_loss: 0.2625
# Epoch 7/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2624 - val_loss: 0.2618
# Epoch 8/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2617 - val_loss: 0.2611
# Epoch 9/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2610 - val_loss: 0.2604
# Epoch 10/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2600 - val_loss: 0.2590
# Epoch 11/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2584 - val_loss: 0.2575
# Epoch 12/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2569 - val_loss: 0.2561
# Epoch 13/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2556 - val_loss: 0.2548
# Epoch 14/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2542 - val_loss: 0.2532
# Epoch 15/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2527 - val_loss: 0.2517
# Epoch 16/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2512 - val_loss: 0.2502
# Epoch 17/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2498 - val_loss: 0.2488
# Epoch 18/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2486 - val_loss: 0.2476
# Epoch 19/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2475 - val_loss: 0.2466
# Epoch 20/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2466 - val_loss: 0.2458
# Epoch 21/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2458 - val_loss: 0.2450
# Epoch 22/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2452 - val_loss: 0.2444
# Epoch 23/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2446 - val_loss: 0.2438
# Epoch 24/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2440 - val_loss: 0.2433
# Epoch 25/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2436 - val_loss: 0.2428
# Epoch 26/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2431 - val_loss: 0.2424
# Epoch 27/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2427 - val_loss: 0.2419
# Epoch 28/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2422 - val_loss: 0.2415
# Epoch 29/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2418 - val_loss: 0.2410
# Epoch 30/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2414 - val_loss: 0.2406
# Epoch 31/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2409 - val_loss: 0.2402
# Epoch 32/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2405 - val_loss: 0.2397
# Epoch 33/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2400 - val_loss: 0.2392
# Epoch 34/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2395 - val_loss: 0.2387
# Epoch 35/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2390 - val_loss: 0.2381
# Epoch 36/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2384 - val_loss: 0.2375
# Epoch 37/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2377 - val_loss: 0.2368
# Epoch 38/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2371 - val_loss: 0.2360
# Epoch 39/50
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2363 - val_loss: 0.2351
# Epoch 40/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2353 - val_loss: 0.2340
# Epoch 41/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2342 - val_loss: 0.2327
# Epoch 42/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2328 - val_loss: 0.2313
# Epoch 43/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2314 - val_loss: 0.2297
# Epoch 44/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2299 - val_loss: 0.2282
# Epoch 45/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2284 - val_loss: 0.2266
# Epoch 46/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2270 - val_loss: 0.2252
# Epoch 47/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2257 - val_loss: 0.2239
# Epoch 48/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2244 - val_loss: 0.2226
# Epoch 49/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2232 - val_loss: 0.2214
# Epoch 50/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2221 - val_loss: 0.2202

# %% [markdown]
# # Visualize

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
