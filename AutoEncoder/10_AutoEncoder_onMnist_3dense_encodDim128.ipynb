# %%
from keras.layers import Input, Dense
from keras.models import Model

from keras.datasets import mnist, cifar100
import numpy as np

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# # Model

# %%
# size of encoded representations
encoding_dim = 128

# input placeholder
input_img = Input(shape=(784,))


# encoded representation of the input
encoded = Dense(600, activation='relu')(input_img)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# map input to its encoded representation
encoder = Model(input_img, encoded)


# input to the decoder
encoded_input = Input(shape=(encoding_dim,))

# reconstruction of the input
decoded = Dense(128, activation='sigmoid')(encoded_input)
decoded = Dense(256, activation='sigmoid')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# decoder model
decoder = Model(encoded_input, decoded)

# map an input to its reconstruction
out = decoder(encoder(input_img))
autoencoder = Model(input_img,out)

# %%
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# model_1 (Model)              (None, 128)               564440
# _________________________________________________________________
# model_2 (Model)              (None, 784)               251024
# =================================================================
# Total params: 815,464
# Trainable params: 815,464
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.3341 - val_loss: 0.2708
# Epoch 2/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2676 - val_loss: 0.2654
# Epoch 3/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2649 - val_loss: 0.2642
# Epoch 4/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2641 - val_loss: 0.2635
# Epoch 5/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2636 - val_loss: 0.2631
# Epoch 6/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2631 - val_loss: 0.2626
# Epoch 7/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2625 - val_loss: 0.2620
# Epoch 8/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2619 - val_loss: 0.2613
# Epoch 9/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2613 - val_loss: 0.2608
# Epoch 10/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2606 - val_loss: 0.2599
# Epoch 11/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2595 - val_loss: 0.2585
# Epoch 12/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2579 - val_loss: 0.2570
# Epoch 13/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2565 - val_loss: 0.2558
# Epoch 14/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2553 - val_loss: 0.2546
# Epoch 15/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2540 - val_loss: 0.2532
# Epoch 16/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2527 - val_loss: 0.2517
# Epoch 17/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2512 - val_loss: 0.2503
# Epoch 18/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2498 - val_loss: 0.2489
# Epoch 19/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2486 - val_loss: 0.2477
# Epoch 20/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2475 - val_loss: 0.2467
# Epoch 21/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2466 - val_loss: 0.2458
# Epoch 22/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2458 - val_loss: 0.2450
# Epoch 23/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2451 - val_loss: 0.2443
# Epoch 24/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2444 - val_loss: 0.2437
# Epoch 25/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2439 - val_loss: 0.2431
# Epoch 26/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2433 - val_loss: 0.2426
# Epoch 27/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2428 - val_loss: 0.2421
# Epoch 28/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2423 - val_loss: 0.2415
# Epoch 29/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2418 - val_loss: 0.2410
# Epoch 30/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2413 - val_loss: 0.2405
# Epoch 31/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2408 - val_loss: 0.2401
# Epoch 32/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2404 - val_loss: 0.2395
# Epoch 33/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2398 - val_loss: 0.2389
# Epoch 34/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2392 - val_loss: 0.2382
# Epoch 35/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2384 - val_loss: 0.2373
# Epoch 36/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2374 - val_loss: 0.2361
# Epoch 37/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2363 - val_loss: 0.2349
# Epoch 38/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2351 - val_loss: 0.2337
# Epoch 39/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2340 - val_loss: 0.2325
# Epoch 40/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2328 - val_loss: 0.2313
# Epoch 41/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2318 - val_loss: 0.2302
# Epoch 42/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2307 - val_loss: 0.2291
# Epoch 43/50
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2296 - val_loss: 0.2279
# Epoch 44/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2284 - val_loss: 0.2267
# Epoch 45/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2271 - val_loss: 0.2253
# Epoch 46/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2256 - val_loss: 0.2236
# Epoch 47/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2239 - val_loss: 0.2218
# Epoch 48/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2220 - val_loss: 0.2199
# Epoch 49/50
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.2202 - val_loss: 0.2181
# Epoch 50/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.2185 - val_loss: 0.2165

# %% [markdown]
# # Visualize

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

n = 15 
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
